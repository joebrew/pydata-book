# %%
# Launch with ipython --pylab to get inline plots (if not ipython notebook)

# if ipython notebook:
# %matplotlib inline


import numpy
import matplotlib
from matplotlib import pylab, mlab, pyplot
np = numpy
plt = pyplot

from IPython.core.pylabtools import figsize, getfigs

from pylab import *
from numpy import *

# %%
plot(np.arange(10))

# %%
# FIGURES AND SUBPLOTS

# %%
# Create a new figure object:
fig = plt.figure()

# %%
# Once created, add subplots
ax1 = fig.add_subplot(2, 2, 1) # it'll be two by two and we're selecting the
# first of 4 subplots

# %%
# Create more subplots 
ax2 = fig.add_subplot(2, 2, 2,)
ax3 = fig.add_subplot(2, 2, 3)

# %%
# When you plot, it'll draw on the last figure and subplot (creating if necess)
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'k--') 
# k-- is a style option specifying black dashed line

# %%
# add some additional plots
_ = ax1.hist(randn(100), bins=20, color='k', alpha=0.3)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))

# %%
fig

# %%
# plt.subplots creates new figure with multiple subplots
fig, axes = plt.subplots(2, 3)

# %%
axes
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x000000000AF17E10>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x000000000B745550>]], dtype=object)

# %%
# you can specify sharex and sharey to get same axes

# %%
# Adjusting the spacing around subplots:
subplots_adjust(left=None, 
                bottom=None,
                right=None,
                top=None,
                wspace=None,
                hspace=None)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
# COLORS, MARKERS AND LINE STYLES

# %%
# plot x versus y with green dashes:
x = randn(100)
y = randn(100)
plot(x, y, 'g--')

# %%
# you don't have to combine color and line style into a single string:
plot(x, y, linestyle='--', color='g')

# %%
# you can add markers for the points
plt.plot(randn(30).cumsum(), 'ko--')

# %%
# the above, more explicitly:
plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
# you can alter subsequent point interpolation with drawstyle option
data = randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 'k--', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %%
# TICKS, LABELS, AND LEGENDS
# one can use pyplot interface, or object-oriented matplotlib API

# %%
# pyplot has xlim, xticks, xticklabels, etc.
# calling without parameters just returns what you already have
plt.xlim()
# Out:
# (0.0, 1.0)

# %%
# calling with parameters sets axis explicitly
plt.xlim([0, 10])
# Out:
# (0, 10)

# %%
# figure of random walk
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)

# %%
ax.plot(randn(1000).cumsum())

# %%
# change ticks, etc.
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')
# lastly, give names to x axis and set_title

# %%
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')

# %%
fig

# %%
# adding legends
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1,)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')

# %%
ax.legend(loc='best')

# %%
fig

# %%
# Annotations and drawing on a subplot

# %%
#ax.text(x, y, 'Hello', family='monospace', fontsize=10)

# %%
import pandas as pd
from datetime import datetime
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('ch08/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']
spx.plot(ax=ax, style='k-')

crisis_data = [
(datetime(2007, 10, 11), 'Peak of bull market'),
(datetime(2008, 3, 12), 'Bear Stearns Fails'),
(datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 50),
            xytext=(date, spx.asof(date) + 200),
            arrowprops=dict(facecolor='black'),
            horizontalalignment='left', verticalalignment='top')
# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in 2008-2009 financial crisis')

# %%
# Drawing shapes (referred to as patches)
#  create a patch object (shp)
# and add it to subplot by calling ax.add_patch(shp)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], 
                    [0.35, 0.4],
                    [0.2, 0.6]],
                   color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
# SAVING PLOTS TO A FILE
plt.savefig('figpath.svg')

# %%
# options:
#plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %%
# Customizing matplot features (pp. 231-232)

# %%
# PLOTTING FUNCTIONS IN PANDAS

# %%
# Line plots
import numpy as np
import pandas as pd
from pandas import Series
s = Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
s.plot()

# %%
# DataFrame's plot method by default plots each column
# as a different line
from pandas import DataFrame
df = DataFrame(np.random.randn(10, 4).cumsum(0),
               columns=['A', 'B', 'C', 'D'],
               index=np.arange(0, 100, 10))

# %%
df.plot()

# %%
# Series.plot method arguments:
# label = label for plot legend
# ax = matplotlib subplot object to plot on.  If nothing, uses active subplot
# style = style string, such as 'ko--' to be passed to matplotlib
# alpha = plot fill opacity (0 to 1)
# kind = can be line, bar, barh, or kde
# logy = using logarithmic scale for y axis
# use_index = use the object index for tick albels
# rot = rotation orf tick labels (0-360)
# xticks = values to use for x axis ticks
# yticks = values to use for y axis ticks
# xlim/ ylim
# grid = display axis grid (on by default)

# in addition, DataFrame has some of its own arguments
# subplots = plot each DataFrame Column in a separate subplot
# sharex/ sharey
# fixsize = size of figure to create as tuple
# title = string
# legend = boolean
# sort_columns = plot columns in alphabetical order

# %%
# BAR PLOTS

# %%
# simply need to bar kind='bar' (vertical) or kind='barh' (horizontal)

# %%
fig, axes = plt.subplots(2, 1)

# %%
data = Series(np.random.rand(16), index=list('abcdefghijklmnop'))

# %%
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)

# %%
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7)

# %%
fig

# %%
df = DataFrame(np.random.randn(6, 4),
               index=['one', 'two', 'three', 'four', 'five', 'six'],
               columns=pd.Index(['A', 'B', 'C', 'D'],
                                name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.548488  0.510491  0.312279  1.156443
# two   -1.419279 -1.046992 -0.827620 -0.058767
# three -1.543871  0.388332  0.287810 -1.550190
# four  -0.477650 -0.925751 -0.210121 -0.706446
# five   0.113991 -1.017222  0.815292  0.160431
# six   -0.466328 -0.100172 -1.142466 -0.949653
#
# [6 rows x 4 columns]

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh', stacked=True, alpha=0.5)

# %%
# useful to use value_counts and barplot together
# for seeing frequency of object (say, s)
# s.value_counts().plot(kind='bar')

# %%
# TIPPING DATA
tips = pd.read_csv('ch08/tips.csv')
party_counts = pd.crosstab(tips.day, tips.size)

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3
#
# [4 rows x 6 columns]

# %%
party_counts = party_counts.ix[:, 2:5] # getting rid of 1 and 6 columns
# since there aren't that many

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1
#
# [4 rows x 4 columns]

# %%
# normalize to sum to 1
party_pcts = party_counts.div(party_counts.sum(1).astype(float), axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241
#
# [4 rows x 4 columns]

# %%
party_pcts.plot(kind='bar', stacked=True)

# %%
# HISTOGRAMS AND DENSITY PLOTS
# histogram of tip percentages of total bill
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
tips['tip_pct']
# Out:
# 0     0.059447
# 1     0.160542
# 2     0.166587
# 3     0.139780
# 4     0.146808
# 5     0.186240
# 6     0.228050
# 7     0.116071
# 8     0.130319
# 9     0.218539
# 10    0.166504
# 11    0.141804
# 12    0.101816
# 13    0.162778
# 14    0.203641
# ...
# 229    0.130199
# 230    0.083299
# 231    0.191205
# 232    0.291990
# 233    0.136490
# 234    0.193175
# 235    0.124131
# 236    0.079365
# 237    0.035638
# 238    0.130338
# 239    0.203927
# 240    0.073584
# 241    0.088222
# 242    0.098204
# 243    0.159744
# Name: tip_pct, Length: 244, dtype: float64

# %%
tips['tip_pct'].hist(bins=50)

# %%
# Density (using kernel density estimate)
# simply specify kind='kde'
tips['tip_pct'].plot(kind='kde')

# %%
# often plotted together:
comp1 = np.random.normal(0, 1, size=200) # N(0, 1)
comp2 = np.random.normal(10, 2, size=200) # N(10, 4)
values = Series(np.concatenate([comp1, comp2]))
values
# Out:
# 0     0.244415
# 1    -0.147368
# 2     1.032545
# 3    -0.040581
# 4    -0.523509
# 5    -0.223175
# 6    -1.126461
# 7    -1.309320
# 8     0.005518
# 9     0.671266
# 10    0.548987
# 11   -1.399181
# 12    1.505100
# 13    0.026064
# 14    0.603648
# ...
# 385    11.919123
# 386     8.961849
# 387     5.665805
# 388    10.049465
# 389     7.905175
# 390    11.779204
# 391    10.260272
# 392    11.247823
# 393    12.024157
# 394     8.308932
# 395     5.327880
# 396     6.084121
# 397    12.014938
# 398    11.568296
# 399     9.518661
# Length: 400, dtype: float64

# %%
values.hist(bins=100, alpha=0.3, color='k', normed=True)
values.plot(kind='kde', style='k--')

# %%
# figure out how to plot together

# %%
# SCATTER PLOTS

# %%
macro = pd.read_csv('ch08/macrodata.csv')

# %%
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]

# %%
trans_data = np.log(data).diff().dropna()

# %%
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560
#
# [5 rows x 4 columns]

# %%
plt.scatter(trans_data['m1'], trans_data['unemp'])
plt.title('Changes in log %s vs log %s' % ('m1', 'unemp'))

# %%
# scatter_matrix
pd.scatter_matrix(trans_data, diagonal='kde', color='k', alpha=0.3)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x00000000174344E0>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x000000001ABAA978>]], dtype=object)

# %%
# PLOTTING MAPS: Visualizing Haiti earthquake crisis data
data = pd.read_csv('ch08/Haiti.csv')

# %%
data
# Out:
#     Serial                                     INCIDENT TITLE  \
# 0     4052  * URGENT * Type O blood donations needed in #J...
# 1     4051                     Food-Aid sent to Fondwa, Haiti
# 2     4050  how haiti is right now and how it was during t...
# 3     4049                                        Lost person
# 4     4042                                 Citi Soleil school
# 5     4041                           Radio Commerce in Sarthe
# 6     4040                   Contaminated water in Baraderes.
# 7     4039     Violence at &quot;arcahaie bas Saint-Ard&quot;
# 8     4038                          No electricity in pernier
# 9     4037  Shelter and food needed at Lamentin 54 and Rue...
# 10    4036  Food needed, House collapsed in 1ere Section S...
# 11    4035                      Clogged toilet in canape vert
# 12    4034  Tent shelter and food needed on Lapot St. Carr...
# 13    4033                           Help needed in Brochette
# ...

# %%
data[['INCIDENT TITLE', 'LATITUDE', 'LONGITUDE']][:10]
# Out:
#                                       INCIDENT TITLE   LATITUDE   LONGITUDE
# 0  * URGENT * Type O blood donations needed in #J...  18.233333  -72.533333
# 1                     Food-Aid sent to Fondwa, Haiti  50.226029    5.729886
# 2  how haiti is right now and how it was during t...  22.278381  114.174287
# 3                                        Lost person  44.407062    8.933989
# 4                                 Citi Soleil school  18.571084  -72.334671
# 5                           Radio Commerce in Sarthe  18.593707  -72.310079
# 6                   Contaminated water in Baraderes.  18.482800  -73.638800
# 7     Violence at &quot;arcahaie bas Saint-Ard&quot;  18.415000  -73.195000
# 8                          No electricity in pernier  18.517443  -72.236841
# 9  Shelter and food needed at Lamentin 54 and Rue...  18.547790  -72.410010
#
# [10 rows x 3 columns]

# %%
data['CATEGORY'][:6]
# Out:
# 0          1. Urgences | Emergency, 3. Public Health,
# 1    1. Urgences | Emergency, 2. Urgences logistiqu...
# 2    2. Urgences logistiques | Vital Lines, 8. Autr...
# 3                            1. Urgences | Emergency,
# 4                            1. Urgences | Emergency,
# 5                       5e. Communication lines down,
# Name: CATEGORY, dtype: object

# %%
data.describe()
# Out:
#             Serial     LATITUDE    LONGITUDE
# count  3593.000000  3593.000000  3593.000000
# mean   2080.277484    18.611495   -72.322680
# std    1171.100360     0.738572     3.650776
# min       4.000000    18.041313   -74.452757
# 25%    1074.000000    18.524070   -72.417500
# 50%    2163.000000    18.539269   -72.335000
# 75%    3088.000000    18.561820   -72.293570
# max    4052.000000    50.226029   114.174287
#
# [8 rows x 3 columns]

# %%
# Clean bad locations and remove missing categories:
data = data[(data.LATITUDE > 18) &
            (data.LATITUDE < 20) &
            (data.LONGITUDE > -75) &
            (data.LONGITUDE < -70) &
            data.CATEGORY.notnull()]

# %%
# function to get a list of all the categories
# and to split each category into a code and english name
def to_cat_list(catstr):
    stripped = (x.strip() for x in catstr.split(','))
    return [x for x in stripped if x]

def get_all_categories(cat_series):
    cat_sets = (set(to_cat_list(x)) for x in cat_series)
    return sorted(set.union(*cat_sets))

def get_english(cat):
    code, names = cat.split('.')
    if '|' in names:
        names = names.split(' | ')[1]
    return code, names.strip()

# %%
# test get english
get_english('2. Urgences logistiques | Vital Lines')
# Out:
# ('2', 'Vital Lines')

# %%
# make a dict mapping code to name because we'll use the codes for the analysis
# (note, using generator expression instead of list comprehension)
all_cats = get_all_categories(data.CATEGORY)

# Generator expression
english_mapping = dict(get_english(x) for x in all_cats)

# %%
# examples
english_mapping['2a'], english_mapping['6c']
# Out:
# ('Food Shortage', 'Earthquake and aftershocks')

# %%
# add indicator (dummy) variables, one for each category
def get_code(seq):
    return [x.split('.')[0] for x in seq if x]

# %%
all_codes = get_code(all_cats)
code_index = pd.Index(np.unique(all_codes))
dummy_frame = DataFrame(np.zeros((len(data), len(code_index))),
                        index=data.index, columns=code_index)

# %%
dummy_frame.ix[:, :6]
# Out:
#     1  1a  1b  1c  1d  2
# 0   0   0   0   0   0  0
# 4   0   0   0   0   0  0
# 5   0   0   0   0   0  0
# 6   0   0   0   0   0  0
# 7   0   0   0   0   0  0
# 8   0   0   0   0   0  0
# 9   0   0   0   0   0  0
# 10  0   0   0   0   0  0
# 11  0   0   0   0   0  0
# 12  0   0   0   0   0  0
# 13  0   0   0   0   0  0
# 14  0   0   0   0   0  0
# 15  0   0   0   0   0  0
# 16  0   0   0   0   0  0
# 17  0   0   0   0   0  0
# 18  0   0   0   0   0  0
# 19  0   0   0   0   0  0
# 20  0   0   0   0   0  0
# 21  0   0   0   0   0  0
# 22  0   0   0   0   0  0
# 23  0   0   0   0   0  0
# 24  0   0   0   0   0  0
# 25  0   0   0   0   0  0
# 26  0   0   0   0   0  0
# 27  0   0   0   0   0  0
# 28  0   0   0   0   0  0
# 29  0   0   0   0   0  0
# 30  0   0   0   0   0  0
# 31  0   0   0   0   0  0
# 32  0   0   0   0   0  0
# 33  0   0   0   0   0  0
# 34  0   0   0   0   0  0
# 35  0   0   0   0   0  0
# 36  0   0   0   0   0  0
# 37  0   0   0   0   0  0
# 38  0   0   0   0   0  0
# ...

# %%
# now set appropriate entires of each row to 1, then join with data
for row, cat in zip(data.index, data.CATEGORY):
    codes = get_code(to_cat_list(cat))
    dummy_frame.ix[row, codes] = 1

# %%
data = data.join(dummy_frame.add_prefix('category_'))

# %%
data.ix[:, 10:15]
# Out:
#     category_1  category_1a  category_1b  category_1c  category_1d
# 0            1            0            0            0            0
# 4            1            0            0            0            0
# 5            0            0            0            0            0
# 6            0            0            0            0            0
# 7            0            0            0            0            0
# 8            0            0            0            0            0
# 9            0            0            0            0            0
# 10           0            1            0            0            0
# 11           0            0            0            0            0
# 12           0            0            0            0            0
# 13           0            0            0            0            0
# 14           0            0            0            0            0
# 15           0            0            0            0            0
# ...

# %%
# Map time!
#conda install basemap ???
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-96-c2ce32946b22> in <module>()
#       1 # Map time!
#       2 #conda install basemap ???
# ----> 3 from mpl_toolkits.basemap import Basemap
#       4 import matplotlib.pyplot as plt
#
# ImportError: No module named basemap

# %%
# Lots of spatial stuff here, but cna't import basemap
