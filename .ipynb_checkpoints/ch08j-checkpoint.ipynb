# %%
# Launch with ipython --pylab to get inline plots (if not ipython notebook)

# if ipython notebook:
# %matplotlib inline


import numpy
import matplotlib
from matplotlib import pylab, mlab, pyplot
np = numpy
plt = pyplot

from IPython.core.pylabtools import figsize, getfigs

from pylab import *
from numpy import *

# %%
plot(np.arange(10))

# %%
# FIGURES AND SUBPLOTS

# %%
# Create a new figure object:
fig = plt.figure()

# %%
# Once created, add subplots
ax1 = fig.add_subplot(2, 2, 1) # it'll be two by two and we're selecting the
# first of 4 subplots

# %%
# Create more subplots 
ax2 = fig.add_subplot(2, 2, 2,)
ax3 = fig.add_subplot(2, 2, 3)

# %%
# When you plot, it'll draw on the last figure and subplot (creating if necess)
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'k--') 
# k-- is a style option specifying black dashed line

# %%
# add some additional plots
_ = ax1.hist(randn(100), bins=20, color='k', alpha=0.3)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))

# %%
fig

# %%
# plt.subplots creates new figure with multiple subplots
fig, axes = plt.subplots(2, 3)

# %%
axes
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x000000000B47F860>,
#         <matplotlib.axes.AxesSubplot object at 0x000000000B497940>,
#         <matplotlib.axes.AxesSubplot object at 0x000000000B6BF6D8>],
#        [<matplotlib.axes.AxesSubplot object at 0x000000000B6DD828>,
#         <matplotlib.axes.AxesSubplot object at 0x000000000BB62128>,
#         <matplotlib.axes.AxesSubplot object at 0x000000000BCC5E48>]], dtype=object)

# %%
# you can specify sharex and sharey to get same axes

# %%
# Adjusting the spacing around subplots:
subplots_adjust(left=None, 
                bottom=None,
                right=None,
                top=None,
                wspace=None,
                hspace=None)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
# COLORS, MARKERS AND LINE STYLES

# %%
# plot x versus y with green dashes:
x = randn(100)
y = randn(100)
plot(x, y, 'g--')

# %%
# you don't have to combine color and line style into a single string:
plot(x, y, linestyle='--', color='g')

# %%
# you can add markers for the points
plt.plot(randn(30).cumsum(), 'ko--')

# %%
# the above, more explicitly:
plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
# you can alter subsequent point interpolation with drawstyle option
data = randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 'k--', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %%
# TICKS, LABELS, AND LEGENDS
# one can use pyplot interface, or object-oriented matplotlib API

# %%
# pyplot has xlim, xticks, xticklabels, etc.
# calling without parameters just returns what you already have
plt.xlim()
# Out:
# (0.0, 1.0)

# %%
# calling with parameters sets axis explicitly
plt.xlim([0, 10])
# Out:
# (0, 10)

# %%
# figure of random walk
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)

# %%
ax.plot(randn(1000).cumsum())

# %%
# change ticks, etc.
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')
# lastly, give names to x axis and set_title

# %%
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')

# %%
fig

# %%
# adding legends
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1,)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')

# %%
ax.legend(loc='best')

# %%
fig

# %%
# Annotations and drawing on a subplot

# %%
#ax.text(x, y, 'Hello', family='monospace', fontsize=10)

# %%
import pandas as pd
from datetime import datetime
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('ch08/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']
spx.plot(ax=ax, style='k-')

crisis_data = [
(datetime(2007, 10, 11), 'Peak of bull market'),
(datetime(2008, 3, 12), 'Bear Stearns Fails'),
(datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 50),
            xytext=(date, spx.asof(date) + 200),
            arrowprops=dict(facecolor='black'),
            horizontalalignment='left', verticalalignment='top')
# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in 2008-2009 financial crisis')

# %%
# Drawing shapes (referred to as patches)
#  create a patch object (shp)
# and add it to subplot by calling ax.add_patch(shp)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], 
                    [0.35, 0.4],
                    [0.2, 0.6]],
                   color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
# SAVING PLOTS TO A FILE
plt.savefig('figpath.svg')

# %%
# options:
#plt.savefig('figpath.png', dpi=400, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-46-8f75ab29ac84> in <module>()
#       1 # options:
# ----> 2 plt.savefig('figpath.png', dpi=400, bbox_inches='tight')
#
# c:\Users\BrewJR\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in savefig(*args, **kwargs)
#     559 def savefig(*args, **kwargs):
#     560     fig = gcf()
# --> 561     return fig.savefig(*args, **kwargs)
#     562
#     563
#
# c:\Users\BrewJR\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\figure.pyc in savefig(self, *args, **kwargs)
#    1419             self.set_frameon(frameon)
#    1420
# -> 1421         self.canvas.print_figure(*args, **kwargs)
#    1422
#    1423         if frameon:
#
# c:\Users\BrewJR\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2167                     **kwargs)
#    2168                 renderer = self.figure._cachedRenderer
# -> 2169                 bbox_inches = self.figure.get_tightbbox(renderer)
#    2170
#    2171                 bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# c:\Users\BrewJR\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\figure.pyc in get_tightbbox(self, renderer)
#    1562                 bb.append(ax.get_tightbbox(renderer))
#    1563
# -> 1564         _bbox = Bbox.union([b for b in bb if b.width != 0 or b.height != 0])
#    1565
#    1566         bbox_inches = TransformedBbox(_bbox,
#
# c:\Users\BrewJR\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\transforms.pyc in union(bboxes)
#     712         Return a :class:`Bbox` that contains all of the given bboxes.
#     713         """
# --> 714         assert(len(bboxes))
#     715
#     716         if len(bboxes) == 1:
#
# AssertionError:

# %%
# Customizing matplot features (pp. 231-232)

# %%
# PLOTTING FUNCTIONS IN PANDAS

# %%
# Line plots
import numpy as np
s = Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
s.plot()

# %%
# DataFrame's plot method by default plots each column
# as a different line
from pandas import DataFrame
df = DataFrame(np.random.randn(10, 4).cumsum(0),
               columns=['A', 'B', 'C', 'D'],
               index=np.arange(0, 100, 10))

# %%
df.plot()

# %%
# Series.plot method arguments:
# label = label for plot legend
# ax = matplotlib subplot object to plot on.  If nothing, uses active subplot
# style = style string, such as 'ko--' to be passed to matplotlib
# alpha = plot fill opacity (0 to 1)
# kind = can be line, bar, barh, or kde
# logy = using logarithmic scale for y axis
# use_index = use the object index for tick albels
# rot = rotation orf tick labels (0-360)
# xticks = values to use for x axis ticks
# yticks = values to use for y axis ticks
# xlim/ ylim
# grid = display axis grid (on by default)

# in addition, DataFrame has some of its own arguments
# subplots = plot each DataFrame Column in a separate subplot
# sharex/ sharey
# fixsize = size of figure to create as tuple
# title = string
# legend = boolean
# sort_columns = plot columns in alphabetical order

# %%
# BAR PLOTS

# %%
# simply need to bar kind='bar' (vertical) or kind='barh' (horizontal)

# %%
fig, axes = plt.subplots(2, 1)

# %%
data = Series(np.random.rand(16), index=list('abcdefghijklmnop'))

# %%
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)

# %%
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7)

# %%
fig

# %%
df = DataFrame(np.random.randn(6, 4),
               index=['one', 'two', 'three', 'four', 'five', 'six'],
               columns=pd.Index(['A', 'B', 'C', 'D'],
                                name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.653971 -0.134295 -1.187881  0.786644
# two   -0.703986  0.548746 -0.471205 -1.365328
# three -0.683809 -0.948220  0.811776  1.991801
# four   0.087961  2.216926 -0.513546 -0.348210
# five   0.579325  0.041540  0.142840 -0.487712
# six   -0.807974 -2.034877  0.184179  0.307661
#
# [6 rows x 4 columns]

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh', stacked=True, alpha=0.5)

# %%
# useful to use value_counts and barplot together
# for seeing frequency of object (say, s)
# s.value_counts().plot(kind='bar')

# %%
# TIPPING DATA
tips = pd.read_csv('ch08/tips.csv')
party_counts = pd.crosstab(tips.day, tips.size)

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3
#
# [4 rows x 6 columns]

# %%
party_counts = party_counts.ix[:, 2:5] # getting rid of 1 and 6 columns
# since there aren't that many

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1
#
# [4 rows x 4 columns]

# %%
# normalize to sum to 1
party_pcts = party_counts.div(party_counts.sum(1).astype(float), axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241
#
# [4 rows x 4 columns]

# %%
party_pcts.plot(kind='bar', stacked=True)

# %%
# HISTOGRAMS AND DENSITY PLOTS
# histogram of tip percentages of total bill
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
tips['tip_pct']
# Out:
# 0     0.059447
# 1     0.160542
# 2     0.166587
# 3     0.139780
# 4     0.146808
# 5     0.186240
# 6     0.228050
# 7     0.116071
# 8     0.130319
# 9     0.218539
# 10    0.166504
# 11    0.141804
# 12    0.101816
# 13    0.162778
# 14    0.203641
# ...
# 229    0.130199
# 230    0.083299
# 231    0.191205
# 232    0.291990
# 233    0.136490
# 234    0.193175
# 235    0.124131
# 236    0.079365
# 237    0.035638
# 238    0.130338
# 239    0.203927
# 240    0.073584
# 241    0.088222
# 242    0.098204
# 243    0.159744
# Name: tip_pct, Length: 244, dtype: float64

# %%
tips['tip_pct'].hist(bins=50)

# %%
# Density (using kernel density estimate)
# simply specify kind='kde'
tips['tip_pct'].plot(kind='kde')

# %%
# often plotted together:
comp1 = np.random.normal(0, 1, size=200) # N(0, 1)
comp2 = np.random.normal(10, 2, size=200) # N(10, 4)
values = Series(np.concatenate([comp1, comp2]))
values
# Out:
# 0     1.641811
# 1    -1.033504
# 2    -0.018150
# 3     0.433450
# 4     0.191396
# 5     0.505300
# 6     0.062522
# 7    -1.092413
# 8    -0.338933
# 9    -0.085139
# 10   -0.171264
# 11    0.891096
# 12   -0.461534
# 13    0.923848
# 14   -0.364086
# ...
# 385     9.541815
# 386     9.967807
# 387     7.257752
# 388    11.525698
# 389    10.739961
# 390     7.610989
# 391    10.978618
# 392    10.042073
# 393     8.517431
# 394    11.377394
# 395    10.362627
# 396    10.524128
# 397     7.309451
# 398     8.167133
# 399     7.449581
# Length: 400, dtype: float64

# %%
values.hist(bins=100, alpha=0.3, color='k', normed=True)

# %%
values.plot(kind='kde', style='k--')

# %%
# figure out how to plot together
